# %% [markdown]
# # Data Augmentation

# %%
# Importing Libraries

import cv2
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ### Image rotation:
# We can specify how much degree the image needs to be rotated between 0 and 360.

# %%
# Data Augmentation

path  = r'C:\Users\prabhitha.nagarajan\Documents\Projects\Input_Image\tesla.jpg'

img = np.expand_dims(cv2.imread(path),0)

# ImageDataGenerator rotation
datagen = ImageDataGenerator(rotation_range=50, fill_mode='nearest')
print(datagen)

# iterator
aug_iter = datagen.flow(img, batch_size=1)

# generate samples and plot
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15,15))

# generate batch of images
for i in range(3):

    # convert to unsigned integers
    image = next(aug_iter)[0].astype('uint8')
 
    # plot image
    ax[i].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    ax[i].axis('off')

# %% [markdown]
# ### Image Shift:
# We can shift the image both horizontally and vertically.

# %%
path  = r'C:\Users\prabhitha.nagarajan\Documents\Projects\Input_Image\tesla.jpg'

img = np.expand_dims(cv2.imread(path),0)

# ImageDataGenerator rotation
datagen = ImageDataGenerator(width_shift_range=0.3, height_shift_range=0.3)
print(datagen)

# iterator
aug_iter = datagen.flow(img, batch_size=1)

# generate samples and plot
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15,15))

# generate batch of images
for i in range(3):

    # convert to unsigned integers
    image = next(aug_iter)[0].astype('uint8')
 
    # plot image
    ax[i].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    ax[i].axis('off')

# %% [markdown]
# ### Image Flip:
# We can flip the image. The first image is flipped horizontally and the third one is flipped vertically.

# %%
path  = r'C:\Users\prabhitha.nagarajan\Documents\Projects\Input_Image\tesla.jpg'

img = np.expand_dims(cv2.imread(path),0)

# ImageDataGenerator rotation
datagen = ImageDataGenerator(horizontal_flip=True, vertical_flip=True)
print(datagen)

# iterator
aug_iter = datagen.flow(img, batch_size=1)

# generate samples and plot
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15,15))

# generate batch of images
for i in range(3):

    # convert to unsigned integers
    image = next(aug_iter)[0].astype('uint8')
 
    # plot image
    ax[i].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    ax[i].axis('off')

# %% [markdown]
# ### Image Brightness:
# We can adjust the brightness of the image. The first image is darker compared to the last one.

# %%
path  = r'C:\Users\prabhitha.nagarajan\Documents\Projects\Input_Image\tesla.jpg'

img = np.expand_dims(cv2.imread(path),0)

# ImageDataGenerator rotation
datagen = ImageDataGenerator(brightness_range=[0.4,2.5])
print(datagen)

# iterator
aug_iter = datagen.flow(img, batch_size=1)

# generate samples and plot
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15,15))

# generate batch of images
for i in range(3):

    # convert to unsigned integers
    image = next(aug_iter)[0].astype('uint8')
 
    # plot image
    ax[i].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    ax[i].axis('off')

# %% [markdown]
# ### Image Zoom:
# We can zoom in and zoom out the image.

# %%
path  = r'C:\Users\prabhitha.nagarajan\Documents\Projects\Input_Image\tesla.jpg'

img = np.expand_dims(cv2.imread(path),0)

# ImageDataGenerator rotation
datagen = ImageDataGenerator(zoom_range=0.4)
print(datagen)

# iterator
aug_iter = datagen.flow(img, batch_size=1)

# generate samples and plot
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15,15))

# generate batch of images
for i in range(3):

    # convert to unsigned integers
    image = next(aug_iter)[0].astype('uint8')
 
    # plot image
    ax[i].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    ax[i].axis('off')
